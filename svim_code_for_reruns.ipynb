# %%
#importing libraries
import pandas as pd
import matplotlib
import seaborn as sns
import scipy.stats as stats
import matplotlib.pyplot as plt
import numpy as np
import statsmodels
from statsmodels.stats import multitest
import statistics
from math import sqrt
from statsmodels.stats.power import TTestIndPower
from SigProfilerExtractor import sigpro as sig
import os.path
import glob
import fnmatch
import os
import shutil
import subprocess

def listdir(dirname, pattern="*"):
    return fnmatch.filter(os.listdir(dirname), pattern)

# %%
for x in listdir("/Volumes/UTUCproject/TO_DRIVE", "*_T_*"):
    bam_path = "/Volumes/UTUCproject/TO_DRIVE/" + x + "/" + x + ".aligned.bam"
    output_path = "/Volumes/UTUCproject/TO_DRIVE/" + x + "/"
    if os.path.isfile(bam_path):
        potential_vcf_path = output_path + "variants.vcf"
        if not os.path.exists(potential_vcf_path):
            print(bam_path)
            subprocess.run(["svim", "alignment", output_path, bam_path, "/Volumes/UTUCproject/TO_DRIVE/hg19.fa", "--all_bnds", "--segment_overlap_tolerance", "20", "--min_sv_size",  "10", "--sample", x])
# Out:
# /Volumes/UTUCproject/TO_DRIVE/TL-22-BG7DFVNW_T_CSQ1/TL-22-BG7DFVNW_T_CSQ1.aligned.bam
# 2023-06-12 15:30:50,875 [INFO   ]  ****************** Start SVIM, version 1.4.2 ******************
# 2023-06-12 15:30:50,884 [INFO   ]  CMD: python3 /Users/ren/opt/anaconda3/bin/svim alignment /Volumes/UTUCproject/TO_DRIVE/TL-22-BG7DFVNW_T_CSQ1/ /Volumes/UTUCproject/TO_DRIVE/TL-22-BG7DFVNW_T_CSQ1/TL-22-BG7DFVNW_T_CSQ1.aligned.bam /Volumes/UTUCproject/TO_DRIVE/hg19.fa --all_bnds --segment_overlap_tolerance 20 --min_sv_size 10 --sample TL-22-BG7DFVNW_T_CSQ1
# 2023-06-12 15:30:50,885 [INFO   ]  WORKING DIR: /Volumes/UTUCproject/TO_DRIVE/TL-22-BG7DFVNW_T_CSQ1
# 2023-06-12 15:30:50,885 [INFO   ]  PARAMETER: sub, VALUE: alignment
# 2023-06-12 15:30:50,885 [INFO   ]  PARAMETER: working_dir, VALUE: /Volumes/UTUCproject/TO_DRIVE/TL-22-BG7DFVNW_T_CSQ1
# 2023-06-12 15:30:50,885 [INFO   ]  PARAMETER: bam_file, VALUE: /Volumes/UTUCproject/TO_DRIVE/TL-22-BG7DFVNW_T_CSQ1/TL-22-BG7DFVNW_T_CSQ1.aligned.bam
# 2023-06-12 15:30:50,885 [INFO   ]  PARAMETER: genome, VALUE: /Volumes/UTUCproject/TO_DRIVE/hg19.fa
# 2023-06-12 15:30:50,885 [INFO   ]  PARAMETER: verbose, VALUE: False
# 2023-06-12 15:30:50,885 [INFO   ]  PARAMETER: min_mapq, VALUE: 20
# 2023-06-12 15:30:50,885 [INFO   ]  PARAMETER: min_sv_size, VALUE: 10
# 2023-06-12 15:30:50,885 [INFO   ]  PARAMETER: max_sv_size, VALUE: 100000
# 2023-06-12 15:30:50,885 [INFO   ]  PARAMETER: segment_gap_tolerance, VALUE: 10
# 2023-06-12 15:30:50,885 [INFO   ]  PARAMETER: segment_overlap_tolerance, VALUE: 20
# 2023-06-12 15:30:50,885 [INFO   ]  PARAMETER: partition_max_distance, VALUE: 1000
# 2023-06-12 15:30:50,885 [INFO   ]  PARAMETER: distance_normalizer, VALUE: 900
# 2023-06-12 15:30:50,885 [INFO   ]  PARAMETER: cluster_max_distance, VALUE: 0.3
# 2023-06-12 15:30:50,885 [INFO   ]  PARAMETER: all_bnds, VALUE: True
# 2023-06-12 15:30:50,886 [INFO   ]  PARAMETER: del_ins_dup_max_distance, VALUE: 1.0
# 2023-06-12 15:30:50,886 [INFO   ]  PARAMETER: trans_sv_max_distance, VALUE: 500
# 2023-06-12 15:30:50,886 [INFO   ]  PARAMETER: skip_genotyping, VALUE: False
# 2023-06-12 15:30:50,886 [INFO   ]  PARAMETER: minimum_score, VALUE: 3
# 2023-06-12 15:30:50,886 [INFO   ]  PARAMETER: homozygous_threshold, VALUE: 0.8
# 2023-06-12 15:30:50,886 [INFO   ]  PARAMETER: heterozygous_threshold, VALUE: 0.2
# 2023-06-12 15:30:50,886 [INFO   ]  PARAMETER: minimum_depth, VALUE: 4
# 2023-06-12 15:30:50,886 [INFO   ]  PARAMETER: sample, VALUE: TL-22-BG7DFVNW_T_CSQ1
# 2023-06-12 15:30:50,886 [INFO   ]  PARAMETER: types, VALUE: DEL,INS,INV,DUP:TANDEM,DUP:INT,BND
# 2023-06-12 15:30:50,886 [INFO   ]  PARAMETER: sequence_alleles, VALUE: False
# 2023-06-12 15:30:50,886 [INFO   ]  PARAMETER: insertion_sequences, VALUE: False
# 2023-06-12 15:30:50,886 [INFO   ]  PARAMETER: tandem_duplications_as_insertions, VALUE: False
# 2023-06-12 15:30:50,886 [INFO   ]  PARAMETER: interspersed_duplications_as_insertions, VALUE: False
# 2023-06-12 15:30:50,886 [INFO   ]  PARAMETER: read_names, VALUE: False
# 2023-06-12 15:30:50,886 [INFO   ]  PARAMETER: zmws, VALUE: False
# 2023-06-12 15:30:50,886 [INFO   ]  ****************** STEP 1: COLLECT ******************
# 2023-06-12 15:30:50,886 [INFO   ]  MODE: alignment
# 2023-06-12 15:30:50,886 [INFO   ]  INPUT: /Volumes/UTUCproject/TO_DRIVE/TL-22-BG7DFVNW_T_CSQ1/TL-22-BG7DFVNW_T_CSQ1.aligned.bam
# Traceback (most recent call last):
#   File "/Users/ren/opt/anaconda3/bin/svim", line 216, in <module>
#     sys.exit(main())
#   File "/Users/ren/opt/anaconda3/bin/svim", line 91, in main
#     aln_file = pysam.AlignmentFile(options.bam_file)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/hp/747hztxs6gj_6yjs1m6_57r80000gn/T/ipykernel_17180/232884884.py in <module>
#       6         if not os.path.exists(potential_vcf_path):
#       7             print(bam_path)
# ----> 8             subprocess.run(["svim", "alignment", output_path, bam_path, "/Volumes/UTUCproject/TO_DRIVE/hg19.fa", "--all_bnds", "--segment_overlap_tolerance", "20", "--min_sv_size",  "10", "--sample", x])
#       9
#
# ~/opt/anaconda3/lib/python3.9/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     505     with Popen(*popenargs, **kwargs) as process:
#     506         try:
# --> 507             stdout, stderr = process.communicate(input, timeout=timeout)
#     508         except TimeoutExpired as exc:
#     509             process.kill()
#
# ~/opt/anaconda3/lib/python3.9/subprocess.py in communicate(self, input, timeout)
#    1124                 stderr = self.stderr.read()
#    1125                 self.stderr.close()
# -> 1126             self.wait()
#    1127         else:
#    1128             if timeout is not None:
#
# ~/opt/anaconda3/lib/python3.9/subprocess.py in wait(self, timeout)
#    1187             endtime = _time() + timeout
#    1188         try:
# -> 1189             return self._wait(timeout=timeout)
#    1190         except KeyboardInterrupt:
#    1191             # https://bugs.python.org/issue25942
#
# ~/opt/anaconda3/lib/python3.9/subprocess.py in _wait(self, timeout)
#    1915                         if self.returncode is not None:
#    1916                             break  # Another thread waited.
# -> 1917                         (pid, sts) = self._try_wait(0)
#    1918                         # Check the pid and loop as waitpid has been known to
#    1919                         # return 0 even without WNOHANG in odd situations.
#
# ~/opt/anaconda3/lib/python3.9/subprocess.py in _try_wait(self, wait_flags)
#    1873             """All callers to this function MUST hold self._waitpid_lock."""
#    1874             try:
# -> 1875                 (pid, sts) = os.waitpid(self.pid, wait_flags)
#    1876             except ChildProcessError:
#    1877                 # This happens if SIGCLD is set to be ignored or waiting
#
# KeyboardInterrupt:
