# %%
#importing libraries
import pandas as pd
import matplotlib
import seaborn as sns
import scipy.stats as stats
import matplotlib.pyplot as plt
import numpy as np
import statsmodels
from statsmodels.stats import multitest
import statistics
from math import sqrt
from statsmodels.stats.power import TTestIndPower
from SigProfilerExtractor import sigpro as sig
import os.path
import glob
import fnmatch
import os
import shutil
import subprocess

def listdir(dirname, pattern="*"):
    return fnmatch.filter(os.listdir(dirname), pattern)

# %%
#running SVIM on each sample

for x in listdir("/Volumes/UTUCproject/TO_DRIVE", "*_T_*"):
    bam_path = "/Volumes/UTUCproject/TO_DRIVE/" + x + "/" + x + ".aligned.bam"
    output_path = "/Volumes/UTUCproject/TO_DRIVE/" + x + "/"
    if os.path.isfile(bam_path):
        potential_vcf_path = output_path + "variants.vcf"
        if not os.path.exists(potential_vcf_path):
            print(bam_path)
            subprocess.run(["svim", "alignment", output_path, bam_path, "/Volumes/UTUCproject/TO_DRIVE/hg19.fa", "--all_bnds", "--min_sv_size",  "20", "--sample", x])

# %%
#renaming files since SVIM outputs variant.vcf for every file
#so this code labels them by sample name
for x in listdir("/Volumes/UTUCproject/TO_DRIVE", "*_T_*"):
    directory_path = "/Volumes/UTUCproject/TO_DRIVE/" + x + "/"
    listdir(directory_path, "variants.vcf")
